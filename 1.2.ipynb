# %%
# !nvidia-smi
# Out:
# Thu May  9 04:41:52 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   67C    P8              15W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import torch

# Check PyTorch GPU availability
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Is Available: {torch.cuda.is_available()}")
else:
    print("GPU is not available.")
# Out:
# GPU Name: NVIDIA L4
# GPU Is Available: True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
# %cd
# %cd ..
# %cd content/gdrive/MyDrive/ACV/
# !git clone https://github.com/quanhua92/human-pose-estimation-opencv.git
# Out:
# fatal: destination path 'human-pose-estimation-opencv' already exists and is not an empty directory.

# %%
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/TheSopranos
# Out:
# Filename: TheSopranos2171.jpg, Detected pose: face front view
# Filename: TheSopranos2172.jpg, Detected pose: face front view
# Filename: TheSopranos2173.jpg, Detected pose: face front view
# Filename: TheSopranos2174.jpg, Detected pose: face front view
# Filename: TheSopranos2175.jpg, Detected pose: face front view
# Filename: TheSopranos2176.jpg, Detected pose: face front view
# Filename: TheSopranos2177.jpg, Detected pose: others
# Filename: TheSopranos2178.jpg, Detected pose: face front view
# Filename: TheSopranos2179.jpg, Detected pose: face front view
# Filename: TheSopranos2180.jpg, Detected pose: face front view
# Filename: TheSopranos2181.jpg, Detected pose: face front view
# Filename: TheSopranos2182.jpg, Detected pose: others
# Filename: TheSopranos2183.jpg, Detected pose: others
# Filename: TheSopranos2184.jpg, Detected pose: others
# Filename: TheSopranos2185.jpg, Detected pose: others
# Filename: TheSopranos2186.jpg, Detected pose: others
# ...

# %% [markdown]
# Empty Folder function for testing and debugging the openposeModified.py file

# %%
import os
import shutil

def empty_folder(directory):
    for item in os.listdir(directory):
        item_path = os.path.join(directory, item)
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.remove(item_path)  
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)  
        else:
            print(f"Unknown item in the directory: {item_path}")  


directory_path = '/content/trainingGan1/game/class1'


empty_folder(directory_path)
print("Folder has been emptied.")
# Out:
# Folder has been emptied.

# %%
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp2/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/TheIrishman
# Out:
# Filename: TheIrishman2628.jpg, Detected pose: others
# Filename: TheIrishman2629.jpg, Detected pose: others
# Filename: TheIrishman2630.jpg, Detected pose: others
# Filename: TheIrishman2631.jpg, Detected pose: others
# Filename: TheIrishman2632.jpg, Detected pose: others
# Filename: TheIrishman2633.jpg, Detected pose: face front view
# Filename: TheIrishman2634.jpg, Detected pose: face front view
# Filename: TheIrishman2635.jpg, Detected pose: face front view
# Filename: TheIrishman2636.jpg, Detected pose: others
# Filename: TheIrishman2637.jpg, Detected pose: others
# Filename: TheIrishman2638.jpg, Detected pose: others
# Filename: TheIrishman2639.jpg, Detected pose: others
# Filename: TheIrishman2640.jpg, Detected pose: face front view
# Filename: TheIrishman2641.jpg, Detected pose: others
# Filename: TheIrishman2642.jpg, Detected pose: others
# Filename: TheIrishman2643.jpg, Detected pose: others
# Filename: TheIrishman2644.jpg, Detected pose: others
# ...

# %%
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp3/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/TheGodfather
# Out:
# Filename: TheGodfather769.jpg, Detected pose: others
# Filename: TheGodfather770.jpg, Detected pose: face front view
# Filename: TheGodfather771.jpg, Detected pose: others
# Filename: TheGodfather772.jpg, Detected pose: others
# Filename: TheGodfather773.jpg, Detected pose: others
# Filename: TheGodfather774.jpg, Detected pose: others
# Filename: TheGodfather775.jpg, Detected pose: others
# Filename: TheGodfather776.jpg, Detected pose: others
# Filename: TheGodfather777.jpg, Detected pose: others
# Filename: TheGodfather778.jpg, Detected pose: others
# Filename: TheGodfather779.jpg, Detected pose: others
# Filename: TheGodfather780.jpg, Detected pose: others
# Filename: TheGodfather781.jpg, Detected pose: others
# Filename: TheGodfather782.jpg, Detected pose: full-body back view
# Filename: TheGodfather783.jpg, Detected pose: others
# Filename: TheGodfather784.jpg, Detected pose: others
# Filename: TheGodfather785.jpg, Detected pose: others
# ...

# %%
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp4/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/MafiaVideogame
# Out:
# Filename: MafiaVideogame8999.jpg, Detected pose: others
# Filename: MafiaVideogame9000.jpg, Detected pose: others
# Filename: MafiaVideogame9001.jpg, Detected pose: others
# Filename: MafiaVideogame9002.jpg, Detected pose: others
# Filename: MafiaVideogame9003.jpg, Detected pose: others
# Filename: MafiaVideogame9004.jpg, Detected pose: others
# Filename: MafiaVideogame9005.jpg, Detected pose: others
# Filename: MafiaVideogame9006.jpg, Detected pose: others
# Filename: MafiaVideogame9007.jpg, Detected pose: others
# Filename: MafiaVideogame9008.jpg, Detected pose: others
# Filename: MafiaVideogame9009.jpg, Detected pose: others
# Filename: MafiaVideogame9010.jpg, Detected pose: others
# Filename: MafiaVideogame9011.jpg, Detected pose: others
# Filename: MafiaVideogame9012.jpg, Detected pose: full-body back view
# Filename: MafiaVideogame9013.jpg, Detected pose: others
# Filename: MafiaVideogame9014.jpg, Detected pose: others
# Filename: MafiaVideogame9015.jpg, Detected pose: others
# ...

# %%
# %cd
# %cd ..
# %cd content/gdrive/MyDrive/ACV/yolov9

# !python modified_detect.py --img 1280 --conf 0.1 --weights /content/gdrive/MyDrive/ACV/yolov9/yolov9-e.pt --source /content/gdrive/MyDrive/ACV/Data/AugmentedTrain/games/GTAViceCity.mp4 --device 0 --classes 0 --vid-stride 30 --save-crop
# %cd
# %cd ..
# %cd content/human-pose-estimation-opencv
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp5/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/GTAViceCity
# Out:
# /root
# /
# /content/gdrive/MyDrive/ACV/yolov9
# modified_detect: weights=['/content/gdrive/MyDrive/ACV/yolov9/yolov9-e.pt'], source=/content/gdrive/MyDrive/ACV/Data/AugmentedTrain/games/GTAViceCity.mp4, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=[0], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=30
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model summary: 839 layers, 68669632 parameters, 0 gradients
# video 1/1 (1/3345) /content/gdrive/MyDrive/ACV/Data/AugmentedTrain/games/GTAViceCity.mp4: 736x1280 3 persons, 162.1ms
# ...

# %%
# %cd
# %cd ..
# %cd content/gdrive/MyDrive/ACV/yolov9

# !python modified_detect.py --img 1280 --conf 0.1 --weights /content/gdrive/MyDrive/ACV/yolov9/yolov9-e.pt --source /content/gdrive/MyDrive/ACV/Data/AugmentedTrain/games/GTA4.mp4 --device 0 --classes 0 --vid-stride 30 --save-crop
# %cd
# %cd ..
# %cd content/human-pose-estimation-opencv
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp6/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/GTA4
# Out:
# Streaming output truncated to the last 5000 lines.
# Filename: GTA484.jpg, Detected pose: face front view
# Filename: GTA485.jpg, Detected pose: face front view
# Filename: GTA486.jpg, Detected pose: face front view
# Filename: GTA487.jpg, Detected pose: face front view
# Filename: GTA488.jpg, Detected pose: others
# Filename: GTA489.jpg, Detected pose: face front view
# Filename: GTA490.jpg, Detected pose: others
# Filename: GTA491.jpg, Detected pose: face front view
# Filename: GTA492.jpg, Detected pose: others
# Filename: GTA493.jpg, Detected pose: others
# Filename: GTA494.jpg, Detected pose: others
# Filename: GTA495.jpg, Detected pose: face front view
# Filename: GTA496.jpg, Detected pose: face front view
# Filename: GTA497.jpg, Detected pose: face front view
# Filename: GTA498.jpg, Detected pose: face front view
# Filename: GTA499.jpg, Detected pose: face front view
# Filename: GTA4100.jpg, Detected pose: others
# Filename: GTA4101.jpg, Detected pose: others
# ...

# %%
# %cd
# %cd ..
# %cd content/gdrive/MyDrive/ACV/yolov9

# !python modified_detect.py --img 1280 --conf 0.1 --weights /content/gdrive/MyDrive/ACV/yolov9/yolov9-e.pt --source /content/gdrive/MyDrive/ACV/Data/AugmentedTrain/movies/Gotti.mp4 --device 0 --classes 0 --vid-stride 24 --save-crop
# %cd
# %cd ..
# %cd content/human-pose-estimation-opencv
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp7/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/Gotti
# Out:
# Streaming output truncated to the last 5000 lines.
# Filename: Gotti3554.jpg, Detected pose: others
# Filename: Gotti3555.jpg, Detected pose: others
# Filename: Gotti3556.jpg, Detected pose: others
# Filename: Gotti3557.jpg, Detected pose: face front view
# Filename: Gotti3558.jpg, Detected pose: others
# Filename: Gotti3559.jpg, Detected pose: others
# Filename: Gotti3560.jpg, Detected pose: others
# Filename: Gotti3561.jpg, Detected pose: others
# Filename: Gotti3562.jpg, Detected pose: others
# Filename: Gotti3563.jpg, Detected pose: others
# Filename: Gotti3564.jpg, Detected pose: face front view
# Filename: Gotti3565.jpg, Detected pose: others
# Filename: Gotti3566.jpg, Detected pose: others
# Filename: Gotti3567.jpg, Detected pose: others
# Filename: Gotti3568.jpg, Detected pose: others
# Filename: Gotti3569.jpg, Detected pose: others
# Filename: Gotti3570.jpg, Detected pose: others
# Filename: Gotti3571.jpg, Detected pose: face front view
# ...

# %%
# %cd
# %cd ..
# %cd content/human-pose-estimation-opencv
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp5/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/GTAViceCity
# Out:
# Streaming output truncated to the last 5000 lines.
# Filename: GTAViceCity1794.jpg, Detected pose: full-body front view
# Filename: GTAViceCity1795.jpg, Detected pose: others
# Filename: GTAViceCity1796.jpg, Detected pose: face front view
# Filename: GTAViceCity1797.jpg, Detected pose: face front view
# Filename: GTAViceCity1798.jpg, Detected pose: face front view
# Filename: GTAViceCity1799.jpg, Detected pose: others
# Filename: GTAViceCity1800.jpg, Detected pose: others
# Filename: GTAViceCity1801.jpg, Detected pose: face front view
# Filename: GTAViceCity1802.jpg, Detected pose: face front view
# Filename: GTAViceCity1803.jpg, Detected pose: face front view
# Filename: GTAViceCity1804.jpg, Detected pose: others
# Filename: GTAViceCity1805.jpg, Detected pose: others
# Filename: GTAViceCity1806.jpg, Detected pose: others
# Filename: GTAViceCity1807.jpg, Detected pose: others
# Filename: GTAViceCity1808.jpg, Detected pose: others
# ...

# %%
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp4/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/MafiaVideogame
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp6/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/GTA4
# !python openposeModified.py --input_folder /content/gdrive/MyDrive/ACV/yolov9/runs/detect/exp7/crops/person --output_folder /content/gdrive/MyDrive/ACV/openpose/Gotti
# Out:
# Streaming output truncated to the last 5000 lines.
# Filename: Gotti4999.jpg, Detected pose: others
# Filename: Gotti5000.jpg, Detected pose: others
# Filename: Gotti5001.jpg, Detected pose: others
# Filename: Gotti5002.jpg, Detected pose: others
# Filename: Gotti5003.jpg, Detected pose: others
# Filename: Gotti5004.jpg, Detected pose: others
# Filename: Gotti5005.jpg, Detected pose: face front view
# Filename: Gotti5006.jpg, Detected pose: others
# Filename: Gotti5007.jpg, Detected pose: others
# Filename: Gotti5008.jpg, Detected pose: others
# Filename: Gotti5009.jpg, Detected pose: others
# Filename: Gotti5010.jpg, Detected pose: others
# Filename: Gotti5011.jpg, Detected pose: others
# Filename: Gotti5012.jpg, Detected pose: others
# Filename: Gotti5013.jpg, Detected pose: others
# Filename: Gotti5014.jpg, Detected pose: others
# Filename: Gotti5015.jpg, Detected pose: others
# Filename: Gotti5016.jpg, Detected pose: others
# Filename: Gotti5017.jpg, Detected pose: others
# ...
